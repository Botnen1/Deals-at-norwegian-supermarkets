# %%
import pandas as pd

# %%
file = pd.read_csv('deals.csv', sep=',')

# %%
file
# Out:
#           store                   title                  price_per_unit  \
# 0      Bunnpris            Poteter pose                    5 kg•kr 8/kg
# 1      Bunnpris                 Risgrøt               970 g•kr 29,90/kg
# 2      Bunnpris                 Løvbiff            6x100 g•kr 131,67/kg
# 3      Bunnpris  Ramløsa citrus og pære               20x0,33 l•kr 15/l
# 4      Bunnpris      Coca-cola u/sukker               6x1,5 l•kr 7,77/l
# ..          ...                     ...                             ...
# 293  Coop-Extra      L’OR ESPRESSO CAPS      2x10 stykker• kr 3,50/hver
# 294  Coop-Extra          FREIA SMAKFULL  2x270-320 g• maks kr 120,37/kg
# 295  Coop-Extra    DORITOS NACHO CHEESE           2x170 g• kr 147,06/kg
# 296  Coop-Extra      JANUS ULLSETT BARN                             NaN
# 297  Coop-Extra       BØKER TIL FARSDAG                             NaN
#
#         price
# 0       kr 40
# 1       kr 29
# 2       kr 79
# 3       kr 99
# 4    kr 69,90
# ...
